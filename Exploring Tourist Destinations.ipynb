# %% [markdown]
# # Deskripsi Dataset

# %% [markdown]
# Dataset [Indonesia Tourism Destination](https://www.kaggle.com/datasets/aprabowo/indonesia-tourism-destination?resource=download&select=package_tourism.csv) yang tersedia di Kaggle berisi informasi mengenai berbagai destinasi wisata di Indonesia. Dataset ini dibuat oleh pengguna dengan nama aprabowo dan terakhir diperbarui pada tahun 2021. Dataset ini mencakup beberapa kota besar di Indonesia seperti Jakarta, Yogyakarta, Semarang, Bandung, dan Surabaya.

# %% [markdown]
# | Nama Kolom      | Deskripsi                                                                 |
# |-----------------|--------------------------------------------------------------------------|
# | User_Id         | Identitas unik dari pengguna yang memberikan rating atau ulasan.         |
# | Place_Id        | Identitas unik dari destinasi wisata.                                    |
# | Place_Ratings   | Nilai rating yang diberikan oleh pengguna untuk destinasi wisata tersebut.|
# | Location        | Lokasi umum dari destinasi wisata (kota, wilayah, atau daerah tertentu).  |
# | Age             | Umur pengguna yang memberikan rating atau ulasan.                        |
# | Place_Name      | Nama dari destinasi wisata.                                              |
# | Description     | Deskripsi singkat mengenai destinasi wisata.                             |
# | Category        | Kategori dari destinasi wisata (alam, budaya, sejarah, hiburan, dll.).   |
# | City            | Kota di mana destinasi wisata tersebut berada.                           |
# | Price           | Biaya tiket masuk atau harga lainnya yang terkait dengan destinasi wisata.|
# | Rating          | Rating keseluruhan dari destinasi wisata berdasarkan agregasi rating pengguna.|
# | Time_Minutes    | Waktu yang diperlukan untuk mengunjungi atau menikmati destinasi wisata tersebut (dalam menit).|
# | Coordinate      | Koordinat geografis dari lokasi destinasi wisata (latitude dan longitude).|
# | Lat             | Latitude, koordinat geografis lintang dari destinasi wisata.             |
# | Long            | Longitude, koordinat geografis bujur dari destinasi wisata.              |
# | Unnamed: 11     | Kolom yang mungkin kosong atau tidak terdefinisi dalam dataset.          |
# | Unnamed: 12     | Kolom lain yang mungkin kosong atau tidak terdefinisi dalam dataset.     |
# | Package         | Informasi mengenai paket wisata yang tersedia untuk destinasi tersebut, jika ada.|
# | Place_Tourism1  | Destinasi wisata lain yang terkait atau direkomendasikan bersama dengan destinasi utama.|
# | Place_Tourism2  | Destinasi wisata terkait kedua.                                          |
# | Place_Tourism3  | Destinasi wisata terkait ketiga.                                         |
# | Place_Tourism4  | Destinasi wisata terkait keempat.                                        |
# | Place_Tourism5  | Destinasi wisata terkait kelima.                                         |

# %% [markdown]
# # Latar Belakang

# %% [markdown]
# Kondisi saat ini, sekitar 60% destinasi wisata di Indonesia masih memiliki kelemahan seperti kurangnya infrastruktur dan fasilitas pendukung yang memadai seperti akses transportasi, akomodasi, restoran, dan fasilitas rekreasi. Menurut data Kementerian Pariwisata dan Ekonomi Kreatif, hanya 40% destinasi wisata yang memiliki aksesibilitas yang baik. Selain itu, belum optimalnya promosi dan pemasaran destinasi wisata juga menjadi kendala dalam menarik lebih banyak wisatawan. Data menunjukkan bahwa pertumbuhan kunjungan wisatawan mancanegara ke Indonesia hanya 4,2% pada 2022, jauh di bawah negara-negara tetangga seperti Malaysia (23,6%) dan Singapura (14,8%).Menurut laporan Badan Pusat Statistik, sebanyak 17% kawasan wisata alam mengalami kerusakan lingkungan akibat aktivitas pariwisata yang tidak terkendali. Oleh karena itu, analisis destinasi wisata diperlukan untuk memberikan rekomendasi perencanaan pengembangan yang lebih baik, strategi promosi dan pemasaran yang tepat, serta upaya pelestarian lingkungan dan budaya lokal, serta pemberdayaan masyarakat lokal untuk meningkatkan pendapatan dan kesejahteraan mereka dari sektor pariwisata yang saat ini baru menyumbang 4,3% terhadap PDB nasional.<br>
# Maka dari itu saya ingin melakukan evaluasi mendalam terhadap setiap destinasi wisata untuk mengidentifikasi potensi yang dapat ditingkatkan serta kelemahan yang perlu diperbaiki, serta dapat diidentifikasi strategi promosi yang lebih efektif untuk meningkatkan kunjungan wisatawan baik domestik maupun mancanegara.

# %% [markdown]
# # Import Library

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Data Loading

# %%
df_package = pd.read_csv('package_tourism.csv')
df_package.tail()
# Out:
#     Package      City                   Place_Tourism1  \
# 95       96  Surabaya      Ekowisata Mangrove Wonorejo
# 96       97  Surabaya                Ciputra Waterpark
# 97       98  Surabaya    Museum Kesehatan Dr. Adhyatma
# 98       99  Surabaya  Taman Ekspresi Dan Perpustakaan
# 99      100  Surabaya              Taman Buah Surabaya
#
#               Place_Tourism2                  Place_Tourism3  \
# 95     Taman Harmoni Keputih             Taman Kunang-Kunang
# 96             Kenjeran Park         Kebun Binatang Surabaya
# 97  Patung Buddha Empat Rupa            Taman Hiburan Rakyat
# 98   Museum De Javasche Bank  Surabaya Museum (Gedung Siola)
# 99       Hutan Bambu Keputih                Taman Barunawati
#
#                      Place_Tourism4                    Place_Tourism5
# 95  Taman Ekspresi Dan Perpustakaan           Museum De Javasche Bank
# 96      Food Junction Grand Pakuwon          | Atlantis Land Surabaya
# ...

# %%
df_rating = pd.read_csv('tourism_rating.csv')
df_rating.tail()
# Out:
#       User_Id  Place_Id  Place_Ratings
# 9995      300       425              2
# 9996      300        64              4
# 9997      300       311              3
# 9998      300       279              4
# 9999      300       163              2

# %%
df_place = pd.read_csv('tourism_with_id.csv')
df_place.tail()
# Out:
#      Place_Id                                 Place_Name  \
# 432       433                        Museum Mpu Tantular
# 433       434                              Taman Bungkul
# 434       435           Taman Air Mancur Menari Kenjeran
# 435       436               Taman Flora Bratang Surabaya
# 436       437  Gereja Perawan Maria Tak Berdosa Surabaya
#
#                                            Description       Category  \
# 432  Museum Negeri Mpu Tantular adalah sebuah museu...         Budaya
# 433  Taman Bungkul adalah taman wisata kota yang te...  Taman Hiburan
# 434  Air mancur menari atau dancing fountain juga a...  Taman Hiburan
# 435  Taman Flora adalah salah satu taman kota di Su...  Taman Hiburan
# 436  Gereja Katolik Kelahiran Santa Perawan Maria m...  Tempat Ibadah
#
#          City  Price  Rating  Time_Minutes  \
# 432  Surabaya   2000     4.4          45.0
# 433  Surabaya      0     4.6           NaN
# 434  Surabaya      0     4.4          45.0
# ...

# %%
df_user = pd.read_csv('user.csv')
df_user.tail()
# Out:
#      User_Id                     Location  Age
# 295      296    Lampung, Sumatera Selatan   31
# 296      297  Palembang, Sumatera Selatan   39
# 297      298            Bogor, Jawa Barat   38
# 298      299          Sragen, Jawa Tengah   27
# 299      300         Ponorogo, Jawa Timur   26

# %%
# Lakukan join menggunakan metode join()
result = df_rating.join(df_user.set_index('User_Id'), on='User_Id').join(df_place.set_index('Place_Id'), on='Place_Id').join(df_package.set_index('City'), on='City')

result.head()
# Out:
#    User_Id  Place_Id  Place_Ratings               Location  Age  \
# 0        1       179              3  Semarang, Jawa Tengah   20
# 0        1       179              3  Semarang, Jawa Tengah   20
# 0        1       179              3  Semarang, Jawa Tengah   20
# 0        1       179              3  Semarang, Jawa Tengah   20
# 0        1       179              3  Semarang, Jawa Tengah   20
#
#         Place_Name                                        Description  \
# 0  Candi Ratu Boko  Situs Ratu Baka atau Candi Boko (Hanacaraka:ꦕꦤ...
# 0  Candi Ratu Boko  Situs Ratu Baka atau Candi Boko (Hanacaraka:ꦕꦤ...
# 0  Candi Ratu Boko  Situs Ratu Baka atau Candi Boko (Hanacaraka:ꦕꦤ...
# 0  Candi Ratu Boko  Situs Ratu Baka atau Candi Boko (Hanacaraka:ꦕꦤ...
# 0  Candi Ratu Boko  Situs Ratu Baka atau Candi Boko (Hanacaraka:ꦕꦤ...
#
#   Category        City  Price  ...       Lat        Long Unnamed: 11  \
# 0   Budaya  Yogyakarta  75000  ... -7.770542  110.489416         NaN
# ...

# %% [markdown]
# ## Data Cleaning

# %%
# Tampilkan info dataframe
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200000 entries, 0 to 9999
# Data columns (total 23 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   User_Id         200000 non-null  int64
#  1   Place_Id        200000 non-null  int64
#  2   Place_Ratings   200000 non-null  int64
#  3   Location        200000 non-null  object
#  4   Age             200000 non-null  int64
#  5   Place_Name      200000 non-null  object
#  6   Description     200000 non-null  object
#  7   Category        200000 non-null  object
#  8   City            200000 non-null  object
#  9   Price           200000 non-null  int64
#  10  Rating          200000 non-null  float64
#  11  Time_Minutes    92560 non-null   float64
#  12  Coordinate      200000 non-null  object
#  13  Lat             200000 non-null  float64
#  14  Long            200000 non-null  float64
#  15  Unnamed: 11     0 non-null       float64
#  16  Unnamed: 12     200000 non-null  int64
# ...

# %%
#menghapus kolom yang mungkin tidak diperlakukan untuk kebutuhan analisis
result=result.drop(['Unnamed: 11', 'Unnamed: 12'], axis=1)
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200000 entries, 0 to 9999
# Data columns (total 21 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   User_Id         200000 non-null  int64
#  1   Place_Id        200000 non-null  int64
#  2   Place_Ratings   200000 non-null  int64
#  3   Location        200000 non-null  object
#  4   Age             200000 non-null  int64
#  5   Place_Name      200000 non-null  object
#  6   Description     200000 non-null  object
#  7   Category        200000 non-null  object
#  8   City            200000 non-null  object
#  9   Price           200000 non-null  int64
#  10  Rating          200000 non-null  float64
#  11  Time_Minutes    92560 non-null   float64
#  12  Coordinate      200000 non-null  object
#  13  Lat             200000 non-null  float64
#  14  Long            200000 non-null  float64
#  15  Package         200000 non-null  int64
#  16  Place_Tourism1  200000 non-null  object
# ...

# %%
# Cek kolom yang memiliki nilai null
null_columns = result.columns[result.isnull().any()].to_list()
null_columns
# Out:
# ['Time_Minutes', 'Place_Tourism4', 'Place_Tourism5']

# %%
# Isi nilai null
for col in null_columns:
    if result[col].dtype in ['float64', 'int64']:  # Jika kolom numerik
        result[col].fillna(0, inplace=True)
    else:  # Jika kolom string
        result[col].fillna('NaN', inplace=True)

# Tampilkan hasil
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200000 entries, 0 to 9999
# Data columns (total 21 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   User_Id         200000 non-null  int64
#  1   Place_Id        200000 non-null  int64
#  2   Place_Ratings   200000 non-null  int64
#  3   Location        200000 non-null  object
#  4   Age             200000 non-null  int64
#  5   Place_Name      200000 non-null  object
#  6   Description     200000 non-null  object
#  7   Category        200000 non-null  object
#  8   City            200000 non-null  object
#  9   Price           200000 non-null  int64
#  10  Rating          200000 non-null  float64
#  11  Time_Minutes    200000 non-null  float64
#  12  Coordinate      200000 non-null  object
#  13  Lat             200000 non-null  float64
#  14  Long            200000 non-null  float64
#  15  Package         200000 non-null  int64
#  16  Place_Tourism1  200000 non-null  object
# ...

# %%
result.columns
# Out:
# Index(['User_Id', 'Place_Id', 'Place_Ratings', 'Location', 'Age', 'Place_Name',
#        'Description', 'Category', 'City', 'Price', 'Rating', 'Time_Minutes',
#        'Coordinate', 'Lat', 'Long', 'Package', 'Place_Tourism1',
#        'Place_Tourism2', 'Place_Tourism3', 'Place_Tourism4', 'Place_Tourism5'],
#       dtype='object')

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Make Function

# %%
def visualize_time_distribution(df, group_by_col, value_col, title, xlabel):
    # Lakukan pengelompokan berdasarkan kolom yang ditentukan dan hitung total waktu yang dihabiskan
    time_spent = df.groupby(group_by_col)[value_col].sum().reset_index()

    # Visualisasikan distribusi waktu yang dihabiskan
    plt.figure(figsize=(10, 6))
    bars = plt.bar(time_spent[group_by_col], time_spent[value_col], color='skyblue')

    # Menambahkan label pada setiap batang
    for bar in bars:
        yval = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2.0, yval, int(yval), va='bottom')  # Menambahkan nilai di atas batang

    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel('Total Waktu (menit)')
    plt.xticks(rotation=45, ha='right')
    plt.grid(axis='y')
    plt.tight_layout()
    plt.show()
    
def visualize_places_distribution(df, group_by_col, value_col, title, xlabel):
    # Mengelompokkan berdasarkan kolom yang ditentukan dan menghitung jumlah unik value_col
    grouped_data = df.groupby(group_by_col)[value_col].nunique().reset_index()
    
    # Mengganti nama kolom untuk kejelasan
    grouped_data.columns = [group_by_col, 'Number_of_Places']

    # Visualisasi jumlah tempat destinasi berdasarkan kolom yang ditentukan
    plt.figure(figsize=(12, 8))
    bars = plt.bar(grouped_data[group_by_col], grouped_data['Number_of_Places'], color='skyblue')

    # Menambahkan label pada setiap batang
    for bar in bars:
        yval = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2.0, yval, int(yval), va='bottom')  # Menambahkan nilai di atas batang

    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel('Jumlah Tempat Destinasi')
    plt.xticks(rotation=45, ha='right')
    plt.grid(axis='y')
    plt.tight_layout()
    plt.show()
    
def visualize_total_visits(df, group_by_col, title, xlabel):
    # Mengelompokkan berdasarkan kolom yang ditentukan dan menghitung total kunjungan (jumlah baris)
    total_visits = df.groupby(group_by_col).size().reset_index(name='Total_Visits')

    # Visualisasi total kunjungan berdasarkan kolom yang ditentukan
    plt.figure(figsize=(12, 8))
    bars = plt.bar(total_visits[group_by_col], total_visits['Total_Visits'], color='skyblue')

    # Menambahkan label pada setiap batang
    for bar in bars:
        yval = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2.0, yval, int(yval), va='bottom')  # Menambahkan nilai di atas batang

    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel('Total Kunjungan')
    plt.xticks(rotation=45, ha='right')
    plt.grid(axis='y')
    plt.tight_layout()
    plt.show()
    
def visualize_revenue(df, group_by_col, title, xlabel):
    # Menghitung revenue
    df['Revenue'] = df['Price'] * df['User_Id']
    
    # Mengelompokkan berdasarkan kolom yang ditentukan dan menjumlahkan revenue
    total_revenue = df.groupby(group_by_col)['Revenue'].sum().reset_index()

    # Visualisasi distribusi revenue berdasarkan kolom yang ditentukan
    plt.figure(figsize=(12, 8))
    bars = plt.bar(total_revenue[group_by_col], total_revenue['Revenue'], color='skyblue')

    # Menambahkan label pada setiap batang
    for bar in bars:
        yval = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2.0, yval, int(yval), va='bottom')  # Menambahkan nilai di atas batang

    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel('Total Revenue')
    plt.xticks(rotation=45, ha='right')
    plt.grid(axis='y')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Analisis sebaran rating destinasi wisata berdasarkan kota/lokasi dan kategori

# %% [markdown]
# Fungsi: Mengidentifikasi destinasi wisata yang berkualitas tinggi maupun rendah, serta menentukan prioritas pengembangan dan strategi penetapan harga yang tepat.

# %%
# 1. Sebaran Rating Berdasarkan Kota/Lokasi

plt.figure(figsize=(12, 6))

# 1. Sebaran Rating Berdasarkan Kota/Lokasi
sns.barplot(x='City', y='Rating', data=result, estimator=lambda x: sum(x) / len(x))
plt.title('Rata-rata Rating Destinasi Wisata Berdasarkan Kota')
plt.xlabel('Kota/Lokasi')
plt.ylabel('Rata-rata Rating')

# Menambahkan label pada setiap batang
for bar in plt.gca().patches:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval, round(yval, 2), va='bottom', color='black', fontsize=10)  # Menambahkan nilai di atas batang

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# 2. Sebaran Rating Berdasarkan Kategori
plt.figure(figsize=(12, 6))
sns.boxplot(x='Category', y='Rating', data=result)
plt.title('Distribusi Rating Destinasi Wisata Berdasarkan Kategori')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Analisis persebaran destinasi wisata berdasarkan kategori (alam, budaya, dll.) dan ketersediaan objek wisata alam/budaya.

# %% [markdown]
# Fungsi: Mengidentifikasi potensi pengembangan produk wisata yang sesuai dengan sumber daya alam dan budaya lokal, serta mendukung upaya pelestarian lingkungan dan budaya.

# %%
# Visualisasi Distirbusi lokasi destinasi berdasarkan Kategori
visualize_places_distribution(result, 'Category', 'Place_Name', 'Jumlah Tempat Destinasi di Setiap Kategori', 'Kategori')

# %% [markdown]
# ## Bagaimana sebaran kategori destinasi wisata di setiap kota/lokasi?

# %% [markdown]
# Fungsi: Mengidentifikasi jenis destinasi wisata yang dominan di setiap kota/lokasi, untuk membantu diversifikasi produk wisata dan menarik segmen wisatawan yang berbeda.

# %%
# Visualisasi Distirbusi lokasi destinasi berdasarkan Kota
visualize_places_distribution(result, 'City', 'Place_Name', 'Jumlah Tempat Destinasi di Setiap Kota', 'Kota')

# %%
# Menghapus duplikasi berdasarkan Place_Name
unique_places = result.drop_duplicates(subset='Place_Name')

# Membuat pivot table untuk heatmap
pivot_table = unique_places.pivot_table(index='City', columns='Category', aggfunc='size', fill_value=0)

plt.figure(figsize=(14, 8))
sns.heatmap(pivot_table, annot=True, fmt="d", cmap="YlGnBu")
plt.title('Ketersediaan Objek Wisata Alam/Budaya Berdasarkan Kota')
plt.xlabel('Kategori')
plt.ylabel('Kota')
plt.show()

# %% [markdown]
# ## Analisis persebaran usia pengunjung berdasarkan kategori destinasi wisata dan kota/lokasi.

# %% [markdown]
# Fungsi: Membantu menyesuaikan strategi pemasaran dan produk wisata sesuai dengan segmen usia yang ditargetkan di setiap kota/lokasi.

# %%
# Mengelompokkan data berdasarkan kategori dan kota
grouped_data = result.groupby(['Category', 'City'])

# Menghitung rata-rata usia pengunjung di setiap kelompok
average_age = grouped_data['Age'].mean()

# Ubah hasil perhitungan menjadi DataFrame
average_age_df = average_age.reset_index()

# Buat plot menggunakan seaborn
plt.figure(figsize=(12, 6))
sns.barplot(x='City', y='Age', hue='Category', data=average_age_df)
plt.title('Rata-rata Usia Pengunjung berdasarkan Kategori dan Kota/Lokasi')
plt.xlabel('Kota/Lokasi')
plt.ylabel('Rata-rata Usia')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Evaluasi persentase destinasi wisata dengan rating sangat tinggi (di atas 4) dan sangat rendah (di bawah 4)

# %% [markdown]
# Fungsi: Mengidentifikasi destinasi wisata yang menjadi prioritas utama untuk promosi dan pemasaran, serta destinasi yang memerlukan perbaikan kualitas secara mendesak

# %%
# Hitung jumlah destinasi wisata dengan rating di atas 4 dan di bawah 4
above_4 = result[result['Rating'] > 4]['Place_Id'].count()
below_4 = result[result['Rating'] < 4]['Place_Id'].count()

# Hitung persentase
total = above_4 + below_4
above_4_percent = (above_4 / total) * 100
below_4_percent = (below_4 / total) * 100

# Buat diagram lingkaran
labels = ['Rating > 4', 'Rating < 4']
sizes = [above_4_percent, below_4_percent]
colors = ['#ff9999','#66b3ff']
explode = (0.1, 0)  # potong bagian pertama

plt.figure(figsize=(8, 6))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('Persentase Destinasi Wisata berdasarkan Rating')
plt.axis('equal')  # memastikan pie chart berbentuk lingkaran
plt.show()

# %% [markdown]
# ## Adakah korelasi antara rating destinasi wisata dengan harga yang ditawarkan?

# %% [markdown]
# Fungsi: Memahami apakah harga mempengaruhi persepsi pengunjung terhadap kualitas destinasi wisata, untuk membantu menetapkan strategi penetapan harga yang tepat.

# %%
# 3. Sebaran Rating Berdasarkan Harga
plt.figure(figsize=(12, 6))
sns.scatterplot(x='Price', y='Place_Ratings', data=result)
sns.regplot(x='Price', y='Place_Ratings', data=result, scatter=False, color='red')
plt.title('Sebaran Rating Berdasarkan Harga Tiket')
plt.show()

# %% [markdown]
# Dari grafik scatter plot, kita dapat melihat Garis regresi yang menunjukkan bahwa semakin tinggi harga tiket, maka ratingnya cenderung lebih rendah.

# %% [markdown]
# ## Adakah perbedaan signifikan dalam rating destinasi wisata berdasarkan kategori?

# %% [markdown]
# Fungsi: Memahami preferensi wisatawan terhadap jenis destinasi wisata tertentu, untuk membantu mengembangkan produk wisata yang sesuai dengan permintaan pasar.

# %%
# Buat box plot untuk melihat distribusi rating berdasarkan kategori
plt.figure(figsize=(12, 8))
sns.boxplot(x='Category', y='Rating', data=result)
plt.title('Distribusi Rating Destinasi Wisata Berdasarkan Kategori')
plt.xlabel('Kategori Destinasi Wisata')
plt.ylabel('Rating')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Apakah terdapat perbedaan signifikan dalam lamanya pengunjung berada di tempat wisata antar kategori destinasi wisata tertentu?

# %% [markdown]
# Fungsi: Membandingkan durasi kunjungan antara kategori destinasi wisata untuk mengetahui preferensi pengunjung terhadap jenis-jenis destinasi tertentu.<br>
# Informasi yang Diberikan: Apakah pengunjung cenderung menghabiskan lebih banyak waktu di destinasi alam, budaya, sejarah, atau jenis lain dari destinasi wisata.

# %%
# Visualisasi Kategori destinasi dengan Waktu Kunjungan
visualize_time_distribution(result, 'Category', 'Time_Minutes', 
                            'Total Waktu yang Dihabiskan oleh Pengunjung di Setiap Kategori Destinasi',
                            'Kategori Destinasi')

# %% [markdown]
# ## Bagaimana perbandingan total kunjungan wisatawan antara kategori destinasi wisata alam, budaya, sejarah, petualangan, atau kategori lainnya?

# %% [markdown]
# Fungsi: Membandingkan popularitas antara berbagai jenis destinasi wisata untuk memahami preferensi pengunjung.<br>
# Informasi yang Diberikan: Apakah destinasi wisata alam lebih populer daripada destinasi budaya, atau sebaliknya? Apakah ada kategori yang memiliki total kunjungan yang lebih tinggi daripada yang lain?

# %%
visualize_total_visits(result, 'Category', 'Total Kunjungan di Setiap Kategori', 'Kategori')

# %% [markdown]
# ## Bagaimana distribusi total kunjungan wisatawan berdasarkan kelompok usia

# %% [markdown]
# Fungsi: Memahami kontribusi relatif setiap kelompok usia terhadap total kunjungan wisatawan.<br>
# Informasi yang Diberikan: Apakah ada kelompok usia tertentu yang lebih sering mengunjungi destinasi wisata daripada yang lain, dan seberapa besar kontribusinya terhadap total kunjungan?

# %%
visualize_total_visits(result, 'Age', 'Total Kunjungan untuk setiap Umur', 'Umur')

# %%
# Hitung jumlah kunjungan untuk setiap lokasi destinasi
most_visited = result['Place_Name'].value_counts().reset_index()
most_visited.columns = ['Place Name', 'Total Kunjungan']

# Menampilkan lokasi destinasi yang paling sering dikunjungi
print("Lokasi destinasi yang paling sering dikunjungi:")
print(most_visited.head(1))
print(" ")

# Menampilkan lokasi destinasi yang paling jarang dikunjungi
print("Lokasi destinasi yang paling jarang dikunjungi:")
print(most_visited.tail(1))
# Out:
# Lokasi destinasi yang paling sering dikunjungi:
#             Place Name  Total Kunjungan
# 0  Pantai Parangtritis              780
#
# Lokasi destinasi yang paling jarang dikunjungi:
#                Place Name  Total Kunjungan
# 436  Museum Ullen Sentalu              240

# %% [markdown]
# ## Apakah terdapat perbedaan signifikan dalam pendapatan antara kategori destinasi wisata?

# %% [markdown]
# Fungsi: Membandingkan performa keuangan antara berbagai jenis destinasi wisata untuk mengetahui potensi bisnis yang paling menguntungkan.<br>
# Informasi yang Diberikan: Apakah ada kategori destinasi wisata yang secara konsisten menghasilkan pendapatan lebih tinggi dibandingkan dengan yang lain, dan faktor apa yang mungkin mempengaruhinya?

# %%
visualize_revenue(result, 'Category', 'Distribusi Revenue Berdasarkan Kategori', 'Kategori')

# %%
# Hitung pendapatan dari penjualan tiket masuk
result['Total_Revenue'] = result['Price'] * result['User_Id']
result['Total_Revenue'].sum()
# Out:
# 728849590000

# %% [markdown]
# # Kesimpulan
